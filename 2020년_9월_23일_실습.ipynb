# %% [markdown]
# <a href="https://colab.research.google.com/github/YuDeokRin/ICT_innovation_square/blob/main/2020%EB%85%84_9%EC%9B%94_23%EC%9D%BC_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.read_excel("./남북한발전전력량.xlsx")

# %%
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 1       NaN     수력    64    51    49    60  ...    78    77    84    78    58    66
# 2       NaN     화력   484   573   696   803  ...  3343  3430  3581  3427  3402  3523
# 3       NaN    원자력   529   563   565   581  ...  1547  1503  1388  1564  1648  1620
# 4       NaN    신재생     -     -     -     -  ...     -    86   118   151   173   195
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
# 6       NaN     수력   156   150   142   133  ...   132   135   139   130   100   128
# 7       NaN     화력   121   113   105    88  ...    79    80    82    86    90   111
# 8       NaN    원자력     -     -     -     -  ...     -     -     -     -     -     -
#
# [9 rows x 29 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.iloc[[0,5]]
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
#
# [2 rows x 29 columns]

# %%
df_ns = df.iloc[[0,5], 3: ]

# %%
df_ns
# Out:
#    1991  1992  1993  1994  1995  1996  ...  2011  2012  2013  2014  2015  2016
# 0  1186  1310  1444  1650  1847  2055  ...  4969  5096  5171  5220  5281  5404
# 5   263   247   221   231   230   213  ...   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %%
#df_ns의 컴럼 조회
df_ns.columns
# Out:
# Index(['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %% [markdown]
# int 함수

# %%
# 컬럼이름 문자 -> 컬럼 이름 숫자로 변환   int() 함수 
int("1998")
# Out:
# 1998

# %%
#컬럼의 타입을 조회
type(df_ns.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df_ns.columns.map(int)
# Out:
# Int64Index([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#             2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#             2013, 2014, 2015, 2016],
#            dtype='int64')

# %%
df_ns.columns = df_ns.columns.map(int)

# %%
#데이터 프레임 조회
df_ns
# Out:
#    1991  1992  1993  1994  1995  1996  ...  2011  2012  2013  2014  2015  2016
# 0  1186  1310  1444  1650  1847  2055  ...  4969  5096  5171  5220  5281  5404
# 5   263   247   221   231   230   213  ...   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %%
#선그래프 그리기
df_ns.plot()

# %%
df_ns.index=("South", "North")

# %%
df_ns
# Out:
#        1991  1992  1993  1994  1995  1996  ...  2011  2012  2013  2014  2015  2016
# South  1186  1310  1444  1650  1847  2055  ...  4969  5096  5171  5220  5281  5404
# North   263   247   221   231   230   213  ...   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#줄 -> 칸으로
#칸->줄로
#변환하는 명령어 입니다

tdf_ns = df_ns.T

# %%
tdf_ns
# Out:
#      South North
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
tdf_ns.plot()

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

# %%
tdf_ns.plot()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#그래스 크기 설정
tdf_ns.plot(figsize=(20,10))

# %%
tdf_ns.plot(kind='bar')

# %%
tdf_ns.plot(kind='bar',figsize=(15,7))

# %% [markdown]
# 히스토그램

# %%
df1=pd.DataFrame({
    "A":[100, 100, 200, 300,300,300],
    "B":[100, 200,200,200, 300, 300]
})

# %%
df1
# Out:
#      A    B
# 0  100  100
# 1  100  200
# 2  200  200
# 3  300  200
# 4  300  300
# 5  300  300

# %%
df1.plot(kind="hist")

# %%
df1["A"].plot(kind="hist")

# %%
df1["B"].plot(kind="hist")

# %%
df1.plot(kind="hist")

# %%
df1.plot(kind="hist")

# %%
#그래프 바의 속이 비치게 설정 => 투명도
#alpha: 0(완전 투명), 1(완전불투명)
df1.plot(kind="hist", alpha=0.9)

# %%
#그래프 바의 속이 비추게 설정 => 투명도 
#투명도 :  alpha 0 (완전투명), 1(완전 불투명) 
df1.plot(kind="hist",alpha=0.1)

# %%
#투명도를 0.6으로 설정
#강의자료 p119
df1.plot(kind="hist",alpha=0.6)

# %% [markdown]
# 남북한 발전량의 빈도수

# %%
tdf_ns
# Out:
#      South North
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
tdf_ns.plot(kind="hist")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df2 = pd.DataFrame({
    "eng_score":[100, 90, 80, 99, 70],
    "kor_score":[80, 100, 70, 30, 100]
})

# %%
df2
# Out:
#    eng_score  kor_score
# 0        100         80
# 1         90        100
# 2         80         70
# 3         99         30
# 4         70        100

# %%
df2.plot(x = "eng_score", y="kor_score", kind="scatter")

# %%
#강의자료 p121
pd.read_csv("./auto-mpg.csv")
# Out:
#      18.0  8  307.0  130.0   3504.  12.0  70  1 chevrolet chevelle malibu
# 0    15.0  8  350.0  165.0  3693.0  11.5  70  1         buick skylark 320
# 1    18.0  8  318.0  150.0  3436.0  11.0  70  1        plymouth satellite
# 2    16.0  8  304.0  150.0  3433.0  12.0  70  1             amc rebel sst
# 3    17.0  8  302.0  140.0  3449.0  10.5  70  1               ford torino
# 4    15.0  8  429.0  198.0  4341.0  10.0  70  1          ford galaxie 500
# ..    ... ..    ...    ...     ...   ...  .. ..                       ...
# 392  27.0  4  140.0  86.00  2790.0  15.6  82  1           ford mustang gl
# 393  44.0  4   97.0  52.00  2130.0  24.6  82  2                 vw pickup
# 394  32.0  4  135.0  84.00  2295.0  11.6  82  1             dodge rampage
# 395  28.0  4  120.0  79.00  2625.0  18.6  82  1               ford ranger
# 396  31.0  4  119.0  82.00  2720.0  19.4  82  1                chevy s-10
#
# [397 rows x 9 columns]

# %%
#header가 없을 때 
df = pd.read_csv("./auto-mpg.csv",header=None)

# %%
df.rename(columns={0:"mpg",
                  4:"weight"} ,inplace=True
          )

# %%
df
# Out:
#       mpg  1      2      3  weight     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.plot(x="weight", y="mpg",kind="scatter")

# %%
#mpg와 weight 의 공분산
df[["mpg","weight"]].cov()
# Out:
#                 mpg         weight
# mpg       61.089611   -5505.211745
# weight -5505.211745  717140.990526

# %%
#mpg와 weight의 상관관계 
df[["mpg","weight"]].corr()
# Out:
#              mpg    weight
# mpg     1.000000 -0.831741
# weight -0.831741  1.000000

# %%
lst1=[1,2,[3,4],5]

# %%
lst2=lst1[:]

# %%
id(lst1)
# Out:
# 139864314078856

# %%
id(lst2)
# Out:
# 139864314068744

# %%
lst1.append(10)

# %%
lst1
# Out:
# [1, 2, [3, 4], 5, 10]

# %%
lst2
# Out:
# [1, 2, [3, 4], 5]

# %%
#강의자료 p14 객체의 공유
lst2[2].append(100)

# %%
lst1
# Out:
# [1, 2, [3, 4, 100], 5, 10]

# %%
lst2
# Out:
# [1, 2, [3, 4, 100], 5]
